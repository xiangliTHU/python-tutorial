# %% [markdown]
# # 数字

# %% [markdown]
# ## 整型 Integers

# %% [markdown]
# 整型运算，加减乘：

# %%
2 + 2
# Out:
# 4

# %%
3 - 4
# Out:
# -1

# %%
4 * 5
# Out:
# 20

# %% [markdown]
# 在**Python 2.7**中，整型的运算结果只能返回整型，**除法**的结果也不例外。

# %% [markdown]
# 例如`12 / 5`返回的结果并不是2.4，而是2：

# %%
12 / 5
# Out:
# 2

# %% [markdown]
# 幂指数：

# %%
2 ** 5
# Out:
# 32

# %% [markdown]
# 取余：

# %%
32 % 5
# Out:
# 2

# %% [markdown]
# 赋值给变量：

# %%
a = 1
a

# %% [markdown]
# 使用`type()`函数来查看变量类型：

# %%
type(a)
# Out:
# int

# %% [markdown]
# 整型数字的最大最小值

# %% [markdown]
# 在32位系统中，一个整型4个字节，最小值`-2,147,483,648`，最大值`2,147,483,647`。

# %% [markdown]
# 在64位系统中，一个整型8个字节，最小值`-9,223,372,036,854,775,808`，最大值`9,223,372,036,854,775,807`。

# %%
import sys
sys.maxint
# Out:
# 2147483647

# %% [markdown]
# ##长整型 Long Integers

# %% [markdown]
# 当整型超出范围时，Python会自动将整型转化为长整型，不过长整型计算速度会比整型慢。

# %%
a = sys.maxint + 1
print type(a)
# Out:
# <type 'long'>

# %% [markdown]
# 长整型的一个标志是后面以字母L结尾：

# %%
a
# Out:
# 2147483648L

# %% [markdown]
# 可以在赋值时强制让类型为长整型：

# %%
b = 1234L
type(b)
# Out:
# long

# %% [markdown]
# 长整型可以与整型在一起进行计算，返回的类型还是长整型：

# %%
a - 4
# Out:
# 2147483644L

# %% [markdown]
# ## 浮点数 Floating Point Numbers

# %%
a = 1.4
type(a)
# Out:
# float

# %% [markdown]
# 在之前的除法例子`12 / 5`中，假如想要使返回的结果为2.4，可以将它们写成浮点数的形式：

# %%
12.0 / 5.0
# Out:
# 2.4

# %%
12 / 5.0
# Out:
# 2.4

# %%
12.0 / 5
# Out:
# 2.4

# %% [markdown]
# 上面的例子说明，浮点数与整数进行运算时，返回的仍然是浮点数：

# %%
5 + 2.4
# Out:
# 7.4

# %% [markdown]
# 浮点数也可以进行与整数相似的运算，甚至可以取余：

# %%
3.4 - 3.2
# Out:
# 0.19999999999999973

# %%
12.3 + 32.4
# Out:
# 44.7

# %%
2.5 ** 2
# Out:
# 6.25

# %%
3.4 % 2.1
# Out:
# 1.2999999999999998
