# %% [markdown]
# # 字符串

# %% [markdown]
# ## 生成字符串

# %% [markdown]
# **Python**中可以使用一对单引号''或者双引号""生成字符串。

# %%
s = "hello, world"
print s
# Out:
# hello, world

# %%
s = 'hello world'
print s
# Out:
# hello world

# %% [markdown]
# ## 简单操作

# %% [markdown]
# 加法：

# %%
s = 'hello ' + 'world'
s
# Out:
# 'hello world'

# %% [markdown]
# 字符串与数字相乘：

# %%
"echo" * 3
# Out:
# 'echoechoecho'

# %% [markdown]
# 字符串长度：

# %%
len(s)
# Out:
# 11

# %% [markdown]
# ## 字符串方法：
